# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from preprocessing import merge_chembl_papyrus_mutants
from mutant_analysis_accession import *
from mutant_analysis_family import obtain_chembl_family,group_families
from mutant_analysis_organism import annotate_organism_taxonomy

# %% [markdown]
# ##### Define output directory

# %%
output_dir = 'C:\\Users\\gorostiolam\\Documents\\Gorostiola Gonzalez, ' \
             'Marina\\PROJECTS\\6_Mutants_PCM\\DATA\\2_Analysis\\0_mutant_statistics\\2_target_stats'

# %% [markdown]
# #### Calculate statistics per protein accession

# %%
stats = get_statistics_across_accessions('31', '05.5', 'nostereo', 1_000_000, output_dir, save=True)
stats
# Out:
#       accession  connectivity  connectivity_wt  target_id  \
# 0    A0A045ISB3           261            245.0          5
# 1        A2RI47            23             17.0          7
# 2        A3EZI9           794            673.0          7
# 3        A3EZJ3           783            746.0         17
# 4        A4HSF7            50             49.0          2
# ..          ...           ...              ...        ...
# 333      Q9WKE8           111              0.0          6
# 334      Q9Y233          4336           4168.0          3
# 335      Q9Y243           418            408.0          2
# 336      Q9Y2R2           279            272.0          8
# 337      Q9YQ12          1168           1092.0         18
#
#      connectivity_mutant_percentage      l1                 l2  \
# 0                          6.130268  Enzyme          Hydrolase
# 1                         26.086957   Other              Other
# 2                         15.239295  Enzyme           Protease
# 3                          4.725415   Other              Other
# 4                          2.000000  Enzyme              Other
# ..                              ...     ...                ...
# 333                      100.000000  Enzyme              Other
# 334                        3.874539  Enzyme  Phosphodiesterase
# 335                        2.392344  Enzyme             Kinase
# 336                        2.508961  Enzyme        Phosphatase
# 337                        6.506849  Enzyme           Protease
#
#                        l3                            l4  \
# 0                   Other                         Other
# 1                   Other                         Other
# 2         Serine protease       Serine protease PA clan
# 3                   Other                         Other
# 4                   Other                         Other
# ..                    ...                           ...
# 333                 Other                         Other
# 334  Phosphodiesterase 10         Phosphodiesterase 10A
# 335        Protein Kinase      AGC protein kinase group
# 336   Protein Phosphatase  Tyrosine protein phosphatase
# 337     Cysteine protease    Cysteine protease PAC clan
#
#                                   l5  \
# 0                              Other
# 1                              Other
# 2         Serine protease S29 family
# 3                              Other
# 4                              Other
# ..                               ...
# 333                            Other
# 334                            Other
# 335    AGC protein kinase AKT family
# 336                            Other
# 337  Cysteine protease C3A subfamily
#
#                                               Organism HGNC_symbol
# 0                           Mycobacterium tuberculosis         NaN
# 1    Lactococcus lactis subsp. cremoris (strain MG1...         NaN
# 2                                        Hepacivirus C         NaN
# 3                                        Hepacivirus C         NaN
# 4                                  Leishmania infantum         NaN
# ..                                                 ...         ...
# 333                     Human immunodeficiency virus 1         NaN
# 334                               Homo sapiens (Human)      PDE10A
# 335                               Homo sapiens (Human)        AKT3
# 336                               Homo sapiens (Human)      PTPN22
# 337                     Human immunodeficiency virus 1         NaN
#
# [338 rows x 12 columns]

# %% [markdown]
# Check which proteins satisfy certain criteria, for example to mention in the manuscript:

# %%
filter_statistics(stats,
                  min_data=1000,
                  min_percentage=10,
                  min_variants=0,
                  sort_output_by='connectivity')
# Out:
# Accession codes for filtered accessions (14):
# P00533, Q72547, P00519, P15056, P36888, O60885, P10721, Q5S007, Q9UM73, P23443, O75874, P07949, P30968, O14684
# Gene names for filtered accessions:
# EGFR, N/A, ABL1, BRAF;B-Raf, FLT3, BRD4, KIT, LRRK2, ALK, RPS6KB1, IDH1, RET, GNRHR, PTGES
#     accession  connectivity  connectivity_wt  target_id  \
# 39     P00533         13638          11104.0         14
# 284    Q72547          6942           4590.0         46
# 36     P00519          4939           3874.0         15
# 103    P15056          4737           1948.0          2
# 175    P36888          4389           3873.0          8
# 26     O60885          4106           3405.0          6
# 85     P10721          2888           2334.0         18
# 279    Q5S007          2762           1822.0          5
# 331    Q9UM73          2586           1952.0         11
# 130    P23443          2286           1024.0          3
# 28     O75874          2202            304.0          7
# 66     P07949          2123           1842.0          9
# 152    P30968          1921           1465.0         71
# 16     O14684          1437           1205.0          2
#
#      connectivity_mutant_percentage                    l1              l2  \
# 39                        18.580437                Enzyme          Kinase
# 284                       33.880726                Enzyme       Hydrolase
# 36                        21.563069                Enzyme          Kinase
# 103                       58.876926                Enzyme          Kinase
# 175                       11.756664                Enzyme          Kinase
# 26                        17.072577  Epigenetic regulator          Reader
# 85                        19.182825                Enzyme          Kinase
# 279                       34.033309                Enzyme          Kinase
# 331                       24.516628                Enzyme          Kinase
# 130                       55.205599                Enzyme          Kinase
# 28                        86.194369                Enzyme  Oxidoreductase
# 66                        13.235987                Enzyme          Kinase
# 152                       23.737637     Membrane receptor            GPCR
# 16                        16.144746                Enzyme           Other
#
#                                    l3                                      l4  \
# 39                     Protein Kinase                 TK protein kinase group
# 284                             Other                                   Other
# 36                     Protein Kinase                 TK protein kinase group
# 103                    Protein Kinase                TKL protein kinase group
# 175                    Protein Kinase                 TK protein kinase group
# 26                        Bromodomain                                   Other
# 85                     Protein Kinase                 TK protein kinase group
# 279                    Protein Kinase                TKL protein kinase group
# 331                    Protein Kinase                TKL protein kinase group
# 130                    Protein Kinase                AGC protein kinase group
# 28                              Other                                   Other
# 66                     Protein Kinase                 TK protein kinase group
# 152  Peptide receptor (family A GPCR)  Short peptide receptor (family A GPCR)
# 16                              Other                                   Other
#
#                                        l5                        Organism  \
# 39    Tyrosine protein kinase EGFR family            Homo sapiens (Human)
# 284                                 Other  Human immunodeficiency virus 1
# 36     Tyrosine protein kinase Abl family            Homo sapiens (Human)
# 103         TKL protein kinase RAF family            Homo sapiens (Human)
# 175  Tyrosine protein kinase PDGFR family            Homo sapiens (Human)
# 26                                  Other            Homo sapiens (Human)
# 85   Tyrosine protein kinase PDGFR family            Homo sapiens (Human)
# 279        TKL protein kinase LRRK family            Homo sapiens (Human)
# 331        TKL protein kinase STKR family            Homo sapiens (Human)
# 130         AGC protein kinase RSK family            Homo sapiens (Human)
# 28                                  Other            Homo sapiens (Human)
# 66     Tyrosine protein kinase Ret family            Homo sapiens (Human)
# 152                         GnRH receptor            Homo sapiens (Human)
# 16                                  Other            Homo sapiens (Human)
#
#     HGNC_symbol
# 39         EGFR
# 284         NaN
# 36         ABL1
# 103  BRAF;B-Raf
# 175        FLT3
# 26         BRD4
# 85          KIT
# 279       LRRK2
# 331         ALK
# 130     RPS6KB1
# 28         IDH1
# 66          RET
# 152       GNRHR
# 16        PTGES

# %% [markdown]
# ##### Check proteins with no WT data

# %%
stats[stats['connectivity_mutant_percentage'] == 100]
# Out:
#     accession  connectivity  connectivity_wt  target_id  \
# 7      B7UPE2             7              0.0          2
# 9      C6ARS9             4              0.0          2
# 11     K7XJL6            61              0.0          3
# 23     O59010             2              0.0          2
# 40     P00720            17              0.0          4
# 218    P58335             8              0.0          2
# 256    Q0ZMF1           121              0.0          4
# 293    Q8AAK6            28              0.0          6
# 333    Q9WKE8           111              0.0          6
#
#      connectivity_mutant_percentage           l1                           l2  \
# 7                             100.0       Enzyme                  Transferase
# 9                             100.0       Enzyme                    Hydrolase
# 11                            100.0        Other                        Other
# 23                            100.0  Transporter  Electrochemical transporter
# 40                            100.0       Enzyme                    Hydrolase
# 218                           100.0        Other                        Other
# 256                           100.0       Enzyme                     Protease
# 293                           100.0       Enzyme                    Hydrolase
# 333                           100.0       Enzyme                        Other
#
#                   l3     l4     l5  \
# 7              Other  Other  Other
# 9              Other  Other  Other
# 11             Other  Other  Other
# 23             Other  Other  Other
# 40             Other  Other  Other
# 218            Other  Other  Other
# 256  Serine protease  Other  Other
# 293            Other  Other  Other
# 333            Other  Other  Other
#
#                                               Organism HGNC_symbol
# 7    Escherichia coli O127:H6 (strain E2348/69 / EPEC)         NaN
# 9    Rhizobium leguminosarum bv. trifolii (strain W...         NaN
# 11                                       Hepacivirus C         NaN
# 23   Pyrococcus horikoshii (strain ATCC 700860 / DS...         NaN
# 40          Enterobacteria phage T4 (Bacteriophage T4)         NaN
# 218                               Homo sapiens (Human)         NaN
# 256                       Hepatitis C virus subtype 1b         NaN
# 293  Bacteroides thetaiotaomicron (strain ATCC 2914...         NaN
# 333                     Human immunodeficiency virus 1         NaN

# %% [markdown]
# ##### Plot statistics in bubble plots
# To explore the amount of bioactivity data, mutant bioactivity data, and number of variants available per protein

# %%
plot_stats_bubble(stats,
                  hue_property='l1',
                  hue_title='Family classification "L1"',
                  label_condition='connectivity',
                  xy_lims=None,
                  output_dir=output_dir)

# %%
# Zoom into the most populated area
plot_stats_bubble(stats,
                  hue_property='l1',
                  hue_title='Family classification "L1"',
                  label_condition='connectivity_mutant_percentage',
                  xy_lims=[(-0.5,20),(-500,10000)],
                  output_dir=output_dir)

# %%
# Plot only kinases
plot_stats_bubble(stats[stats['l2'] == 'Kinase'],
                  hue_property='l4',
                  hue_title='Family classification "L4"',
                  label_condition='connectivity_mutant_percentage',
                  xy_lims=None,
                  output_dir=output_dir)

# %% [markdown]
# ##### Plot main statistics in histograms
# To explore the density of proteins regarding different properties

# %%
plot_stats_histograms(stats, output_dir)

# %% [markdown]
# #### Calculate statistics per variant (target_id)

# %%
stats_variant = get_statistics_across_variants('31', '05.5', 'nostereo', 1_000_000, output_dir, save=True)
stats_variant
# Out:
#        accession                          variant  connectivity_variant  \
# 0     A0A045ISB3                 A0A045ISB3_F161S                     4
# 1     A0A045ISB3                 A0A045ISB3_I203A                     4
# 2     A0A045ISB3                 A0A045ISB3_I207A                     4
# 3     A0A045ISB3                 A0A045ISB3_I207K                     4
# 4     A0A045ISB3                    A0A045ISB3_WT                   245
# ...          ...                              ...                   ...
# 1644      Q9YQ12       Q9YQ12_V32I_L33F_I54M_V82I                     2
# 1645      Q9YQ12  Q9YQ12_V32I_M46I_I47V_Q58E_I84V                    11
# 1646      Q9YQ12                      Q9YQ12_V82A                     4
# 1647      Q9YQ12                      Q9YQ12_V82F                     3
# 1648      Q9YQ12                        Q9YQ12_WT                  1092
#
#       connectivity  connectivity_wt  target_id  \
# 0              261            245.0          5
# 1              261            245.0          5
# 2              261            245.0          5
# 3              261            245.0          5
# 4              261            245.0          5
# ...            ...              ...        ...
# 1644          1168           1092.0         18
# 1645          1168           1092.0         18
# 1646          1168           1092.0         18
# 1647          1168           1092.0         18
# 1648          1168           1092.0         18
#
#       connectivity_mutant_percentage      l1         l2                 l3  \
# 0                           6.130268  Enzyme  Hydrolase              Other
# 1                           6.130268  Enzyme  Hydrolase              Other
# 2                           6.130268  Enzyme  Hydrolase              Other
# 3                           6.130268  Enzyme  Hydrolase              Other
# 4                           6.130268  Enzyme  Hydrolase              Other
# ...                              ...     ...        ...                ...
# 1644                        6.506849  Enzyme   Protease  Cysteine protease
# 1645                        6.506849  Enzyme   Protease  Cysteine protease
# 1646                        6.506849  Enzyme   Protease  Cysteine protease
# 1647                        6.506849  Enzyme   Protease  Cysteine protease
# 1648                        6.506849  Enzyme   Protease  Cysteine protease
#
#                               l4                               l5  \
# 0                          Other                            Other
# 1                          Other                            Other
# 2                          Other                            Other
# 3                          Other                            Other
# 4                          Other                            Other
# ...                          ...                              ...
# 1644  Cysteine protease PAC clan  Cysteine protease C3A subfamily
# 1645  Cysteine protease PAC clan  Cysteine protease C3A subfamily
# 1646  Cysteine protease PAC clan  Cysteine protease C3A subfamily
# 1647  Cysteine protease PAC clan  Cysteine protease C3A subfamily
# 1648  Cysteine protease PAC clan  Cysteine protease C3A subfamily
#
#                             Organism HGNC_symbol  \
# 0         Mycobacterium tuberculosis         NaN
# 1         Mycobacterium tuberculosis         NaN
# 2         Mycobacterium tuberculosis         NaN
# 3         Mycobacterium tuberculosis         NaN
# 4         Mycobacterium tuberculosis         NaN
# ...                              ...         ...
# 1644  Human immunodeficiency virus 1         NaN
# 1645  Human immunodeficiency virus 1         NaN
# 1646  Human immunodeficiency virus 1         NaN
# 1647  Human immunodeficiency virus 1         NaN
# 1648  Human immunodeficiency virus 1         NaN
#
#       connectivity_variant_percentage  variant_order  \
# 0                            1.532567              2
# 1                            1.532567              3
# 2                            1.532567              5
# 3                            1.532567              4
# 4                           93.869732              1
# ...                               ...            ...
# 1644                         0.171233             10
# 1645                         0.941781              4
# 1646                         0.342466              5
# 1647                         0.256849              6
# 1648                        93.493151              1
#
#       connectivity_variant_fold
# 0                     61.250000
# 1                     61.250000
# 2                     61.250000
# 3                     61.250000
# 4                      1.000000
# ...                         ...
# 1644                 546.000000
# 1645                  99.272727
# 1646                 273.000000
# 1647                 364.000000
# 1648                   1.000000
#
# [1649 rows x 17 columns]

# %% [markdown]
# ##### Filter variants for accessions with mutant percentage over 10% and more than 1,000 bioactivity data

# %%
stats_variant_filtered = filter_statistics(stats_variant,
                                           min_data=1000,
                                           min_percentage=10,
                                           min_variants=0,
                                           sort_output_by='connectivity_mutant_percentage')
variants_filter_tag = 'C1000P10' # To identify in the upcoming plots that the stats were filtered
stats_variant_filtered
# Out:
# Accession codes for filtered accessions (14):
# O75874, P15056, P23443, Q5S007, Q72547, Q9UM73, P30968, P00519, P10721, P00533, O60885, O14684, P07949, P36888
# Gene names for filtered accessions:
# IDH1, BRAF;B-Raf, RPS6KB1, LRRK2, N/A, ALK, GNRHR, ABL1, KIT, EGFR, BRD4, PTGES, RET, FLT3
#     accession       variant  connectivity_variant  connectivity  \
# 123    O75874     O75874_WT                   304          2202
# 117    O75874  O75874_R132C                   307          2202
# 122    O75874  O75874_R132S                     5          2202
# 121    O75874  O75874_R132L                    11          2202
# 119    O75874  O75874_R132G                     6          2202
# ..        ...           ...                   ...           ...
# 857    P36888  P36888_D835V                    12          4389
# 858    P36888  P36888_D835Y                   232          4389
# 859    P36888  P36888_F691L                    38          4389
# 860    P36888  P36888_K663Q                    52          4389
# 861    P36888  P36888_N841I                    70          4389
#
#      connectivity_wt  target_id  connectivity_mutant_percentage      l1  \
# 123            304.0          7                       86.194369  Enzyme
# 117            304.0          7                       86.194369  Enzyme
# 122            304.0          7                       86.194369  Enzyme
# 121            304.0          7                       86.194369  Enzyme
# 119            304.0          7                       86.194369  Enzyme
# ..               ...        ...                             ...     ...
# 857           3873.0          8                       11.756664  Enzyme
# 858           3873.0          8                       11.756664  Enzyme
# 859           3873.0          8                       11.756664  Enzyme
# 860           3873.0          8                       11.756664  Enzyme
# 861           3873.0          8                       11.756664  Enzyme
#
#                  l2              l3                       l4  \
# 123  Oxidoreductase           Other                    Other
# 117  Oxidoreductase           Other                    Other
# 122  Oxidoreductase           Other                    Other
# 121  Oxidoreductase           Other                    Other
# 119  Oxidoreductase           Other                    Other
# ..              ...             ...                      ...
# 857          Kinase  Protein Kinase  TK protein kinase group
# 858          Kinase  Protein Kinase  TK protein kinase group
# 859          Kinase  Protein Kinase  TK protein kinase group
# 860          Kinase  Protein Kinase  TK protein kinase group
# 861          Kinase  Protein Kinase  TK protein kinase group
#
#                                        l5              Organism HGNC_symbol  \
# 123                                 Other  Homo sapiens (Human)        IDH1
# 117                                 Other  Homo sapiens (Human)        IDH1
# 122                                 Other  Homo sapiens (Human)        IDH1
# 121                                 Other  Homo sapiens (Human)        IDH1
# 119                                 Other  Homo sapiens (Human)        IDH1
# ..                                    ...                   ...         ...
# 857  Tyrosine protein kinase PDGFR family  Homo sapiens (Human)        FLT3
# 858  Tyrosine protein kinase PDGFR family  Homo sapiens (Human)        FLT3
# 859  Tyrosine protein kinase PDGFR family  Homo sapiens (Human)        FLT3
# 860  Tyrosine protein kinase PDGFR family  Homo sapiens (Human)        FLT3
# 861  Tyrosine protein kinase PDGFR family  Homo sapiens (Human)        FLT3
#
#      connectivity_variant_percentage  variant_order  connectivity_variant_fold
# 123                        13.805631              3                   4.851974
# 117                        13.941871              2                   4.804560
# 122                         0.227066              7                 295.000000
# 121                         0.499546              5                 134.090909
# 119                         0.272480              6                 245.833333
# ..                               ...            ...                        ...
# 857                         0.273411              8                 322.750000
# 858                         5.285942              2                  16.693966
# 859                         0.865801              6                 101.921053
# 860                         1.184780              5                  74.480769
# 861                         1.594896              4                  55.328571
#
# [217 rows x 17 columns]

# %% [markdown]
# ##### Plot amount of data in each variant for the filtered proteins

# %%
plot_variant_stats_lineplot(stats_variant_filtered,
                            filter_tag=variants_filter_tag,
                            y_column='connectivity_variant',
                            y_label='Number of bioactivity datapoints',
                            xy_lims=None,
                            output_dir=output_dir
                            )

# %%
# Plot zooming in
plot_variant_stats_lineplot(stats_variant_filtered,
                            filter_tag=variants_filter_tag,
                            y_column='connectivity_variant',
                            y_label='Number of bioactivity datapoints',
                            xy_lims=[(0.5,10.5),(0,5000)],
                            output_dir=output_dir
                            )

# %% [markdown]
# ##### Plot correlation between fold-change differences of first and second most populated variants and other variables

# %%
plot_variant_fold_change_stats(stats_variant_filtered,
                               filter_tag=variants_filter_tag,
                               variant_n=2,
                               x_column='target_id',
                               x_label='Number of variants',
                               size_column='connectivity_mutant_percentage',
                               size_label='Mutant %',
                               color='#35193e',
                               output_dir=output_dir)

# %%
plot_variant_fold_change_stats(stats_variant_filtered,
                               filter_tag=variants_filter_tag,
                               variant_n=2,
                               x_column='target_id',
                               x_label='Number of variants',
                               size_column='connectivity',
                               size_label='Bioactivity data',
                               color='#701f57',
                               output_dir=output_dir)

# %% [markdown]
# Check also with a less stringent filter (i.e. only coverage and not bioactivity data)

# %%
stats_variant_filtered_2 = filter_statistics(stats_variant,
                                           min_data=0,
                                           min_percentage=10,
                                           min_variants=0,
                                           sort_output_by='connectivity_mutant_percentage')
variants_filter_tag_2 = 'P10' # To identify in the upcoming plots that the stats were filtered
# Out:
# Accession codes for filtered accessions (95):
# P48735, C1KIQ2, Q62120, O75874, P02511, P01116, P0DOF9, P56690, P13738, P13922, Q9NPD8, P48065, Q15022, P07753, Q9QUR6, D5F1R0, Q9P2K8, Q9NZN5, Q05320, P15056, Q6P988, P23443, Q5NGQ3, Q81R22, P21146, P30613, P36873, Q86WV6, P11678, P15682, Q55664, P21860, P41182, Q10471, Q9EPK8, P00520, P40313, Q9KM66, Q5S007, Q72547, Q8II92, P97714, Q869C3, P96830, P04578, Q15910, Q8NY00, P0A031, Q9UM07, A2RI47, P29994, P9WPP1, P17865, Q9UM73, Q9UHC9, P35520, P30968, Q9H7B4, P00519, P43249, P15038, P05981, P51149, P10721, Q61616, Q06486, P00533, Q5L478, P04585, O60885, Q7KQK5, Q58F21, Q9UGC6, P54098, P0DOF8, P42346, O14684, P9WPP9, Q96HE7, A3EZI9, P49842, P0A749, P07949, P41231, Q13526, P11086, P18090, P61073, A4TVL0, P36888, O60218, O95069, P03420, Q04828, P55859
# Gene names for filtered accessions:
# N/A, N/A, N/A, IDH1, N/A, N/A, N/A, N/A, N/A, N/A, N/A, N/A, N/A, N/A, N/A, N/A, EIF2AK4, N/A, N/A, BRAF;B-Raf, N/A, RPS6KB1, N/A, N/A, N/A, PKLR, N/A, N/A, N/A, N/A, N/A, ERBB3, N/A, N/A, N/A, N/A, N/A, N/A, LRRK2, N/A, N/A, N/A, N/A, N/A, N/A, EZH2, N/A, N/A, PADI4, N/A, ITPR1, N/A, N/A, ALK, NPC1L1, N/A, GNRHR, N/A, ABL1, N/A, N/A, N/A, N/A, KIT, N/A, N/A, EGFR, N/A, N/A, BRD4, N/A, N/A, N/A, N/A, N/A, MTOR, PTGES, N/A, N/A, N/A, N/A, N/A, RET, P2RY2, PIN1, PNMT, ADRB1, CXCR4, N/A, FLT3, AKR1B10, N/A, N/A, AKR1C1, N/A

# %%
plot_variant_fold_change_stats(stats_variant_filtered_2,
                               filter_tag=variants_filter_tag_2,
                               variant_n=2,
                               x_column='target_id',
                               x_label='Number of variants',
                               size_column='connectivity_mutant_percentage',
                               size_label='Mutant %',
                               color='#ad1759',
                               output_dir=output_dir)

# %%
plot_variant_fold_change_stats(stats_variant_filtered_2,
                               filter_tag=variants_filter_tag_2,
                               variant_n=2,
                               x_column='target_id',
                               x_label='Number of variants',
                               size_column='connectivity',
                               size_label='Bioactivity data',
                               color='#e13342',
                               output_dir=output_dir)
